# %% [markdown]
# <a href="https://colab.research.google.com/github/priyanshiyadavnitsgr/Computer-Vision/blob/master/Medicine_finding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
med=cv2.imread('/content/meftal_full.jpeg')[:112,:]
cv2_imshow(med)

gray=cv2.cvtColor(med, cv2.COLOR_BGR2GRAY)
#dst = cv2.fastNlMeansDenoisingColored(gray, None, 15, 15, 7, 21)
gaussian=cv2.GaussianBlur(gray, (9,9), 0)
ret,thresh1 = cv2.threshold(gaussian, 15, 255, cv2.THRESH_TOZERO)
edged=cv2.Canny(thresh1, 200, 100)

cv2_imshow(edged)

_, contours, _= cv2.findContours(edged, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contour_list = []
for contour in contours:
    approx = cv2.approxPolyDP(contour,0.01*cv2.arcLength(contour,True),True)
    area = cv2.contourArea(contour)
    if ((len(approx) > 2) & (area > 5) ):
        contour_list.append(contour)
        
print(len(contour_list))
cv2.drawContours(med, contour_list,  -1, (255,0,0), 2)
cv2_imshow(med)
# Out:
# <PIL.Image.Image image mode=RGB size=225x112 at 0x7FD9A1F40978>
# <PIL.Image.Image image mode=L size=225x112 at 0x7FD9A1F40A20>
# 21
# <PIL.Image.Image image mode=RGB size=225x112 at 0x7FD9A1F408D0>

# %%
paracetamol=cv2.imread('/content/IMG_20191003_140357.jpg')
paracetamol=cv2.resize(paracetamol, (500,500))[60:300,140:400]
cv2_imshow(paracetamol)
# Out:
# <PIL.Image.Image image mode=RGB size=260x240 at 0x7FD9A27956A0>

# %%
paracetamol.shape
# Out:
# (260, 280, 3)

# %%
paracetamol=cv2.imread('/content/IMG_20191003_140357.jpg')
paracetamol=cv2.resize(paracetamol, (500,500))[60:300,140:400]
cv2_imshow(paracetamol)

gray=cv2.cvtColor(paracetamol, cv2.COLOR_BGR2GRAY)
#dst = cv2.fastNlMeansDenoisingColored(gray, None, 15, 15, 7, 21)
gaussian=cv2.GaussianBlur(gray, (11,11), 0)
ret,thresh1 = cv2.threshold(gaussian, 15, 255, cv2.THRESH_TOZERO)
edged=cv2.Canny(thresh1, 100, 100)
print('\n')
cv2_imshow(edged)

_, contours, _= cv2.findContours(edged, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

print(len(contours))

cv2.drawContours(paracetamol, contour_list,  -1, (0,0,255), 2)
print('\n')
cv2_imshow(paracetamol)
# Out:
# <PIL.Image.Image image mode=RGB size=260x240 at 0x7FD9A1F1FC88>
# <PIL.Image.Image image mode=L size=260x240 at 0x7FD9A1F1FC88>
# 32
# <PIL.Image.Image image mode=RGB size=260x240 at 0x7FD9A1F1FBE0>

# %%
paracetamol_test=cv2.imread('/content/IMG_20191003_144101.jpg')
paracetamol_test=cv2.resize(paracetamol_test, (500,500))[150:390,120:380]
cv2_imshow(paracetamol_test)
# Out:
# <PIL.Image.Image image mode=RGB size=260x240 at 0x7FD9A1F6D278>

# %%
paracetamol_test=cv2.imread('/content/IMG_20191003_144101.jpg')
paracetamol_test=cv2.resize(paracetamol_test, (500,500))[150:390,120:380]
cv2_imshow(paracetamol_test)

gray=cv2.cvtColor(paracetamol_test, cv2.COLOR_BGR2GRAY)
#dst = cv2.fastNlMeansDenoisingColored(gray, None, 15, 15, 7, 21)
gaussian=cv2.GaussianBlur(gray, (11,11), 0)
ret,thresh1 = cv2.threshold(gaussian, 15, 255, cv2.THRESH_TOZERO)
edged=cv2.Canny(thresh1, 100, 100)
print('\n')
cv2_imshow(edged)

_, contours, _= cv2.findContours(edged, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

print(len(contours))

cv2.drawContours(paracetamol_test, contour_list,  -1, (0,0,255), 2)
print('\n')
cv2_imshow(paracetamol_test)

# %%
med=cv2.imread('/content/IMG_20191003_144101.jpg')
med=cv2.resize(med, (500,500))[150:390,120:380]
cv2_imshow(med)

gray=cv2.cvtColor(med, cv2.COLOR_BGR2GRAY)
#dst = cv2.fastNlMeansDenoisingColored(gray, None, 15, 15, 7, 21)
gaussian=cv2.GaussianBlur(gray, (9,9), 0)
ret,thresh1 = cv2.threshold(gaussian, 15, 255, cv2.THRESH_TOZERO)
edged=cv2.Canny(thresh1, 200, 100)

cv2_imshow(edged)

_, contours, _= cv2.findContours(edged, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contour_list = []
for contour in contours:
    approx = cv2.approxPolyDP(contour,0.01*cv2.arcLength(contour,True),True)
    area = cv2.contourArea(contour)
    if ((len(approx) > 2) & (area > 5) ):
        contour_list.append(contour)
        
print(len(contour_list))
cv2.drawContours(med, contour_list,  -1, (255,0,0), 2)
cv2_imshow(med)
# Out:
# <PIL.Image.Image image mode=RGB size=260x240 at 0x7FD9A1F1FFD0>
# <PIL.Image.Image image mode=L size=260x240 at 0x7FD9A1F1BF98>
# 16
# <PIL.Image.Image image mode=RGB size=260x240 at 0x7FD9A1F1FFD0>

# %%
def contour_mapping(med):
  gray=cv2.cvtColor(med, cv2.COLOR_BGR2GRAY)

  gaussian=cv2.GaussianBlur(gray, (11,11), 0)
  ret,thresh1 = cv2.threshold(gaussian, 15, 255, cv2.THRESH_TOZERO)
  edged=cv2.Canny(thresh1, 100, 100)

  cv2_imshow(edged)

  _, contours, _= cv2.findContours(edged, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
  contour_list = []
  for contour in contours:
      approx = cv2.approxPolyDP(contour,0.05*cv2.arcLength(contour,True),True)
      area = cv2.contourArea(contour)
      if ((len(approx) > 2) & (area > 5) ):
          contour_list.append(contour)
        
  print(len(contour_list))
  cv2.drawContours(med, contour_list,  -1, (255,0,0), 2)
  cv2_imshow(med)
  
  return edged

# %%
paracetamol=cv2.imread('/content/IMG_20191003_140357.jpg')
paracetamol=cv2.resize(paracetamol, (500,500))[60:300,140:400]

gray=cv2.cvtColor(paracetamol, cv2.COLOR_BGR2GRAY)


base=contour_mapping(paracetamol)
# Out:
# <PIL.Image.Image image mode=L size=260x240 at 0x7FD9A1F7ACC0>
# 23
# <PIL.Image.Image image mode=RGB size=260x240 at 0x7FD9A1F7AD68>

# %%
paracetamol_test=cv2.imread('/content/IMG_20191003_144101.jpg')
paracetamol_test=cv2.resize(paracetamol_test, (500,500))[140:380,110:370]

gray_=cv2.cvtColor(paracetamol_test, cv2.COLOR_BGR2GRAY)
  

test_=contour_mapping(paracetamol_test)
test_.shape
# Out:
# <PIL.Image.Image image mode=L size=260x240 at 0x7FD9A1F7A3C8>
# 23
# <PIL.Image.Image image mode=RGB size=260x240 at 0x7FD9A1F7A400>
# (240, 260)

# %%
def crop_detected_object (image, template, width, height):
    image_gray=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  

    result=cv2.matchTemplate(image_gray, template, cv2.TM_CCOEFF_NORMED)
    min_val, max_val, min_loc, max_loc= cv2.minMaxLoc(result)
    print(' Accuracy: ', max_val,'\n Location of the image: ',  max_loc)

    top_left=max_loc
    bottom_right=(top_left[0]+width, top_left[1]+height)

    cropped=image[ top_left[1]:top_left[1]+height, top_left[0]:top_left[0]+width]

    return cropped

# %%
paracetamol.shape
# Out:
# (240, 260, 3)

# %%
paracetamol_test=cv2.imread('/content/IMG_20191003_144101.jpg')
paracetamol_test=cv2.resize(paracetamol_test, (500,500))

test=crop_detected_object(paracetamol_test, gray, 260, 240)
#cv2_imshow(test)

test1=contour_mapping(test)
#cv2_imshow(test1)

result=cv2.matchTemplate(test_, test1, cv2.TM_CCOEFF_NORMED)
min_val, max_val, min_loc, max_loc= cv2.minMaxLoc(result)
print('Accuracy: ', max_val, '\nLocation: ', max_loc)
# Out:
#  Accuracy:  0.5248748064041138
#  Location of the image:  (118, 137)
# <PIL.Image.Image image mode=L size=260x240 at 0x7FD9A1F7A2B0>
# 24
# <PIL.Image.Image image mode=RGB size=260x240 at 0x7FD9A1F7A668>
# Accuracy:  -0.0066115777008235455
# Location:  (0, 0)

# %%
 _, contours, hierarchy=cv2.findContours(base, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
print('Number of contours' , str(len(contours)))
for contour in contours:
   
    (x,y,w,h) = cv2.boundingRect(contour)
    cv2.rectangle(base, (x,y), (x+20,y+20), (0,255,0), 2)
    #cv2.line(i,(0,y+h), (500,y+h), (255,0,0), 1)
    #print(x,y,w,h)
    
cv2_imshow(base)
# Out:
# Number of contours 62
# <PIL.Image.Image image mode=L size=260x240 at 0x7FD9A1F0DF98>

# %%
cv2_imshow(base-base)
# Out:
# <PIL.Image.Image image mode=L size=260x240 at 0x7FD9A1E78898>

# %%
cv2_imshow(gray[10:80, :50])
# Out:
# <PIL.Image.Image image mode=L size=50x70 at 0x7FD9A1F1B2B0>

# %%
    result=cv2.matchTemplate(base, test, cv2.TM_CCOEFF_NORMED)
    min_val, max_val, min_loc, max_loc= cv2.minMaxLoc(result)
    print('Accuracy: ', max_val, '\nLocation: ', max_loc)
# Out:
# Accuracy:  -0.009293690323829651
# Location:  (0, 0)

# %%
paracetamol1_test=cv2.imread('/content/IMG_20191003_143217.jpg')
paracetamol1_test=cv2.resize(paracetamol_test, (500,500))[150:390,120:380]
#test=contour_mapping(paracetamol_test)

# %%
def crop_detected_object (image, template, width, height):
    image_gray=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  

    result=cv2.matchTemplate(image_gray, template, cv2.TM_CCOEFF_NORMED)
    min_val, max_val, min_loc, max_loc= cv2.minMaxLoc(result)
    print(' Accuracy: ', max_val,'\n Location of the image: ',  max_loc)

    top_left=max_loc
    bottom_right=(top_left[0]+width, top_left[1]+height)

    cropped=image[ top_left[1]:top_left[1]+height, top_left[0]:top_left[0]+width]

    return cropped

# %%
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=260x240 at 0x7FD9A1F1F710>

# %%
def outer_boundary(image):
  med=cv2.resize(image, (100,100)).copy()

  gray=cv2.cvtColor(med, cv2.COLOR_BGR2GRAY)

  gaussian=cv2.GaussianBlur(gray, (11,11), 0)
  ret,thresh1 = cv2.threshold(gaussian, 15, 255, cv2.THRESH_TOZERO)
  edged=cv2.Canny(thresh1, 100, 100)

  #cv2_imshow(edged)

  _, contours, _= cv2.findContours(edged, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
  contour_list = []
  for contour in contours:
      approx = cv2.approxPolyDP(contour,0.05*cv2.arcLength(contour,True),True)
      area = cv2.contourArea(contour)
      if ((len(approx) > 2) & (area > 5) ):
          contour_list.append(contour)
        
  print(len(contour_list))
  contours_poly = [None]*len(contours)
  boundRect = [None]*len(contours)
  centers = [None]*len(contours)
  radius = [None]*len(contours)
  for i, c in enumerate(contours):
        contours_poly[i] = cv2.approxPolyDP(c, 3, True)
        boundRect[i] = cv2.boundingRect(contours_poly[i])
        centers[i], radius[i] = cv2.minEnclosingCircle(contours_poly[i])
    
    
  #drawing = np.zeros((canny_output.shape[0], canny_output.shape[1], 3), dtype=np.uint8)
    
  print(len(contours))

  for i in range(len(contours)):
        #color = (rng.randint(0,256), rng.randint(0,256), rng.randint(0,256))
        #cv2.drawContours(med, contours_poly, i, (0,255,0))
        #cv.rectangle(drawing, (int(boundRect[i][0]), int(boundRect[i][1])), \
          #(int(boundRect[i][0]+boundRect[i][2]), int(boundRect[i][1]+boundRect[i][3])), color, 2)
        cv2.circle(med, (int(centers[i][0]), int(centers[i][1])), int(radius[i]), (0,0,255), 2)
  cv2_imshow(med)
        
  return (med)

# %%
base=outer_boundary(paracetamol)
test=outer_boundary(paracetamol_test)
# Out:
# 28
# 28
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FD9A1E123C8>
# 20
# 22
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FD9A1E12208>

# %%
#cv2_imshow(paracetamol-paracetamol_test)
cv2_imshow(base-test_)
# Out:
# <PIL.Image.Image image mode=L size=260x240 at 0x7FD9A1E72978>

# %% [markdown]
# https://stackoverflow.com/questions/56125062/move-overlap-images-over-one-another-to-get-accurate-difference,
# https://stackoverflow.com/questions/29106702/blend-overlapping-images-in-python
