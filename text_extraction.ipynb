# %%
import pytesseract

# %%
import PIL as pil

# %%
from PIL import Image
im = Image.open("bill_photograph.gif")

# %%
im
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=572x634 at 0x1F759D9FB70>

# %%
left = 155
top = 0
right = 400
bottom = 150
  
# Cropped image of above dimension 
# (It will not change orginal image) 
im1 = im.crop((left, top, right, bottom)) 
  
# Shows the image in image viewer 
im1.show() 
im1
# Out:
# <PIL.Image.Image image mode=P size=245x150 at 0x1F75A1FC518>

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files (x86)\\Tesseract-OCR\\tesseract.exe'
import pytesseract
text=pytesseract.image_to_string(im1)
print(text)
# Out:
# Fusion Company Ltd.
# 101 Rocking avenue
# Suie # 305
# Kolkata~700007
#
# west Bengal
# phn: +901-33-2534-5061.
# va no : vasiss7se
# Retail Invoice

# %%
class image_to_text:
    
    def extraction(image, left, top, right, bottom):
        
        im1 = im.crop((left, top, right, bottom)) 
        text=pytesseract.image_to_string(im1)
        print(text)

    left = 155
    top = 0
    right = 400
    bottom = 150
    im= Image.open("bill_photograph.gif")
    extraction(im,left, top, right, bottom )
# Out:
# Fusion Company Ltd.
# 101 Rocking avenue
# Suie # 305
# Kolkata~700007
#
# west Bengal
# phn: +901-33-2534-5061.
# va no : vasiss7se
# Retail Invoice
